# %% [markdown]
# # Analyzing Biotechnology Related Companies in the Proximity of Aachen, Germany

# %% [markdown]
# ## 1) The description of the problem and a discussion of the background

# %% [markdown]
# A contractor is trying to start their own business in the field of biotechnology. They are young entrepreneurs and have deep knowledge about their area but they do not know exactly where to setup their laboratory. They want to know the locations of the biotechnology related companies and possibly why they are settled in that area. My aim is to provide them sufficient information about the neighborhoods of Aachen and to simplify their decision process. I am going to analyse the geospatial data in the proximity of Aachen. Besides, I will show the distribution of the company locations and explore the data.

# %% [markdown]
# **Lets importe some necessary libraries**

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     certifi-2019.11.28         |   py36h9f0ad1d_1         149 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0     conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36h9f0ad1d_1 conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'V4JR2CSZPYFIZFTFZTFM2QWSBN35YW4WOEMW3BSKHW0TG1OK' # your Foursquare ID
CLIENT_SECRET = 'WIVZ4KIPUMCLPLO1ZQ3TVS53TLC1S2B0O4DLZA3OCRUCL03A' # your Foursquare Secret
VERSION = '20200301'
LIMIT = 500
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: V4JR2CSZPYFIZFTFZTFM2QWSBN35YW4WOEMW3BSKHW0TG1OK
# CLIENT_SECRET:WIVZ4KIPUMCLPLO1ZQ3TVS53TLC1S2B0O4DLZA3OCRUCL03A

# %% [markdown]
# ### Lets assume we live in Aachen, Germany and want to start a bussiness nearby. First let's start by converting the Aachen`s address to its latitude and longitude coordinates

# %%
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent foursquare_agent, as shown below.

address = 'Aachen, Germany'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('latitute and longitute of Aachen: {}, {}'.format(latitude, longitude))
# Out:
# latitute and longitute of Aachen: 50.776351, 6.083862

# %% [markdown]
# ## 2) A description of the data and how it will be used to solve the problem

# %% [markdown]
# - The contractor wants to start business in the field of biotechnology in the proximity of Aachen. For this purpose, I am going to search the venues regarding
#         - genetics
#         - biology
#         - biotechnology
#         - bioscience
#         - DNA
#
# - I am going to introduce all venues within 100 km distance from Aachen.
#
# - I am going to obtain 5 data frames and then combine them together so that I can analyse easily.

# %% [markdown]
# ### Lets start to search for a specific venue category

# %% [markdown]
# let's define a query to search for "genetics" related venues that are within 100km metres from the Aachen.

# %% [markdown]
# ### 2.1. Genetics related venues

# %%
search_query = 'genetic'
radius = 100000
print(search_query + ' .... OK!')
# Out:
# genetic .... OK!

# %% [markdown]
# Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=V4JR2CSZPYFIZFTFZTFM2QWSBN35YW4WOEMW3BSKHW0TG1OK&client_secret=WIVZ4KIPUMCLPLO1ZQ3TVS53TLC1S2B0O4DLZA3OCRUCL03A&ll=50.776351,6.083862&v=20200301&query=genetic&radius=100000&limit=500'

# %% [markdown]
# ### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e6cd730a2e538001b74fd54'},
#  'response': {'venues': [{'id': '59db56b45a2c9117457d61ca',
#     'name': 'Klinische Genetica Mumc+',
#     'location': {'lat': 50.836662,
#      'lng': 5.715358,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.836662,
#        'lng': 5.715358}],
#      'distance': 26778,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '5744ccdfe4b0c0459246b4d6',
#       'name': 'Laboratory',
#       'pluralName': 'Laboratories',
#       'shortName': 'Laboratory',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584191445',
#     'hasPerk': False},
#    {'id': '4d4de72b671fba7a4351f352',
#     'name': 'CECAD at Institute for Genetics',
#     'location': {'address': 'Zülpicher Str. 47a',
#      'lat': 50.92739657634655,
#      'lng': 6.936850854873694,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.92739657634655,
#        'lng': 6.936850854873694}],
#      'distance': 62259,
#      'postalCode': '50674',
#      'cc': 'DE',
#      'city': 'Köln',
#      'state': 'Nordrhein-Westfalen',
#      'country': 'Deutschland',
#      'formattedAddress': ['Zülpicher Str. 47a', '50674 Köln', 'Deutschland']},
#     'categories': [{'id': '4bf58dd8d48988d19b941735',
#       'name': 'College Science Building',
#       'pluralName': 'College Science Buildings',
#       'shortName': 'Science',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/collegeacademicbuildings_science_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584191445',
#     'hasPerk': False},
#    {'id': '55eea84a498eabd1ea6c1551',
#     'name': 'Forensische Genetica',
#     'location': {'address': 'Kapucijnenvoer 33',
#      'lat': 50.87958022274423,
#      'lng': 4.693266859530695,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.87958022274423,
#        'lng': 4.693266859530695}],
#      'distance': 98450,
#      'postalCode': '3000',
#      'cc': 'BE',
#      'city': 'Leuven',
#      'state': 'Vlaams-Brabant',
#      'country': 'België',
#      'formattedAddress': ['Kapucijnenvoer 33', '3000 Leuven', 'België']},
#     'categories': [{'id': '4f4531b14b9074f6e4fb0103',
#       'name': 'Medical Lab',
#       'pluralName': 'Medical Labs',
#       'shortName': 'Medical Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584191445',
#     'hasPerk': False},
#    {'id': '513d90a1e4b07fb438cb31e6',
#     'name': 'Autoimmune Genetics Lab',
#     'location': {'address': 'UZ Leuven Campus Gasthuisberg',
#      'lat': 50.88057991020145,
#      'lng': 4.673076283653961,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.88057991020145,
#        'lng': 4.673076283653961}],
#      'distance': 99872,
#      'postalCode': '3000',
#      'cc': 'BE',
#      'city': 'Leuven',
#      'state': 'Vlaams-Brabant',
#      'country': 'België',
#      'formattedAddress': ['UZ Leuven Campus Gasthuisberg',
#       '3000 Leuven',
#       'België']},
#     'categories': [{'id': '4bf58dd8d48988d1a5941735',
#       'name': 'College Lab',
#       'pluralName': 'College Labs',
#       'shortName': 'Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584191445',
#     'hasPerk': False},
#    {'id': '4c8dc146ad70a14343f1830f',
#     'name': 'Hendrix Genetics',
#     'location': {'address': 'Spoorstraat 69',
#      'lat': 51.64695562065073,
#      'lng': 5.938949495345558,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.64695562065073,
#        'lng': 5.938949495345558}],
#      'distance': 97440,
#      'postalCode': '5831 CK',
#      'cc': 'NL',
#      'city': 'Boxmeer',
#      'state': 'Noord-Brabant',
#      'country': 'Nederland',
#      'formattedAddress': ['Spoorstraat 69', '5831 CK Boxmeer', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584191445',
#     'hasPerk': False},
#    {'id': '5146beece4b0853bfb17538d',
#     'name': 'Umc St.Radboud Human Genetics',
#     'location': {'address': 'geert grooteplein zuid 10',
#      'lat': 51.8246002197266,
#      'lng': 5.86629009246826,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.8246002197266,
#        'lng': 5.86629009246826}],
#      'distance': 117668,
#      'postalCode': '6525 GA',
#      'cc': 'NL',
#      'city': 'Nijmegen',
#      'state': 'Gelderland',
#      'country': 'Nederland',
#      'formattedAddress': ['geert grooteplein zuid 10',
#       '6525 GA Nijmegen',
#       'Nederland']},
#     'categories': [{'id': '4f4531b14b9074f6e4fb0103',
#       'name': 'Medical Lab',
#       'pluralName': 'Medical Labs',
#       'shortName': 'Medical Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584191445',
#     'hasPerk': False},
#    {'id': '4cfe02abd8468cfaff64036c',
#     'name': 'Human Genetics Antropogenetica UMC St. Radboud',
#     'location': {'lat': 51.834980616055134,
#      'lng': 5.917803973496178,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.834980616055134,
#        'lng': 5.917803973496178}],
#      'distance': 118410,
#      'cc': 'NL',
#      'city': 'Nijmegen',
#      'state': 'Gelderland',
#      'country': 'Nederland',
#      'formattedAddress': ['Nijmegen', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584191445',
#     'hasPerk': False}]}}

# %% [markdown]
# ### Get relevant part of JSON and transform it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_genetics = json_normalize(venues)
df_genetics.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '5744ccdfe4b0c0459246b4d6', 'name': 'L...    False
# 1  [{'id': '4bf58dd8d48988d19b941735', 'name': 'C...    False
# 2  [{'id': '4f4531b14b9074f6e4fb0103', 'name': 'M...    False
# 3  [{'id': '4bf58dd8d48988d1a5941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
#
#                          id               location.address location.cc  \
# 0  59db56b45a2c9117457d61ca                            NaN          NL
# 1  4d4de72b671fba7a4351f352             Zülpicher Str. 47a          DE
# 2  55eea84a498eabd1ea6c1551              Kapucijnenvoer 33          BE
# 3  513d90a1e4b07fb438cb31e6  UZ Leuven Campus Gasthuisberg          BE
# 4  4c8dc146ad70a14343f1830f                 Spoorstraat 69          NL
#
#   location.city location.country  location.distance  \
# 0           NaN        Nederland              26778
# 1          Köln      Deutschland              62259
# 2        Leuven           België              98450
# 3        Leuven           België              99872
# 4       Boxmeer        Nederland              97440
#
#                            location.formattedAddress  \
# 0                                        [Nederland]
# 1      [Zülpicher Str. 47a, 50674 Köln, Deutschland]
# 2           [Kapucijnenvoer 33, 3000 Leuven, België]
# 3  [UZ Leuven Campus Gasthuisberg, 3000 Leuven, B...
# 4       [Spoorstraat 69, 5831 CK Boxmeer, Nederland]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 50.836662, 'lng':...     50.836662
# 1  [{'label': 'display', 'lat': 50.92739657634655...     50.927397
# 2  [{'label': 'display', 'lat': 50.87958022274423...     50.879580
# 3  [{'label': 'display', 'lat': 50.88057991020145...     50.880580
# 4  [{'label': 'display', 'lat': 51.64695562065073...     51.646956
#
#    location.lng location.postalCode       location.state  \
# 0      5.715358                 NaN                  NaN
# 1      6.936851               50674  Nordrhein-Westfalen
# 2      4.693267                3000       Vlaams-Brabant
# 3      4.673076                3000       Vlaams-Brabant
# 4      5.938949             5831 CK        Noord-Brabant
#
#                               name    referralId
# 0         Klinische Genetica Mumc+  v-1584191445
# 1  CECAD at Institute for Genetics  v-1584191445
# 2             Forensische Genetica  v-1584191445
# 3          Autoimmune Genetics Lab  v-1584191445
# 4                 Hendrix Genetics  v-1584191445

# %% [markdown]
# ### 2.2. Biology related venues

# %% [markdown]
# We can continue the same procedure for the biology related venues

# %%
search_query = 'biology'
radius = 100000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_biology = json_normalize(venues)
df_biology.head()
# Out:
# biology .... OK!
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d198941735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d1a5941735', 'name': 'C...    False
# 2  [{'id': '4bf58dd8d48988d1a5941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1a5941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d19b941735', 'name': 'C...    False
#
#                          id          location.address location.cc  \
# 0  4cdb217cd549548122353ab2  Joseph-Stelzmann-Str. 9b          DE
# 1  4e9689c95c5cc3f498243ed6        Von-Liebig-Str. 20          DE
# 2  4e5604d7ae6040e96dfd3b6e      Celestijnenlaan 200G          BE
# 3  4f0fae2ae4b0253d4af98901                       NaN          NL
# 4  55c32b7e498ec2a4d07df0bd   Kasteelpark Arenberg 31          BE
#
#   location.city location.country  location.distance  \
# 0          Köln      Deutschland              61222
# 1     Rheinbach      Deutschland              63241
# 2      Heverlee           België              99581
# 3          Best        Nederland              94713
# 4      Heverlee           België              98618
#
#                            location.formattedAddress  \
# 0  [Joseph-Stelzmann-Str. 9b, 50931 Köln, Deutsch...
# 1  [Von-Liebig-Str. 20, 53359 Rheinbach, Deutschl...
# 2      [Celestijnenlaan 200G, 3001 Heverlee, België]
# 3                                  [Best, Nederland]
# 4   [Kasteelpark Arenberg 31, 3001 Heverlee, België]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 50.92538278319003...     50.925383
# 1  [{'label': 'display', 'lat': 50.63178898813339...     50.631789
# 2  [{'label': 'display', 'lat': 50.86227832411388...     50.862278
# 3  [{'label': 'display', 'lat': 51.5075, 'lng': 5...     51.507500
# 4  [{'label': 'display', 'lat': 50.86480386250966...     50.864804
#
#    location.lng location.postalCode       location.state  \
# 0      6.922402               50931  Nordrhein-Westfalen
# 1      6.951376               53359  Nordrhein-Westfalen
# 2      4.674423                3001       Vlaams-Brabant
# 3      5.390278                 NaN        Noord-Brabant
# 4      4.688544                3001       Vlaams-Brabant
#
#                                                 name    referralId
# 0          Max-Planck-Institute for Biology of Aging  v-1584191578
# 1                              Molecular Biology Lab  v-1584191578
# 2  Biomol | Laboratory Of Biomolecular Dynamics, ...  v-1584191578
# 3                                       Biology Room  v-1584191578
# 4                             Functional Biology Lab  v-1584191578

# %% [markdown]
# ### 2.3. Biotechnology related venues

# %%
search_query = 'biotechnology'
radius = 100000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_biotechnology = json_normalize(venues)
df_biotechnology.head()
# Out:
# biotechnology .... OK!
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **We see that there is no biotechnology related company in the proximity of Aachen**

# %% [markdown]
# ### 2.4. Bioscience related venues

# %%
search_query = 'bioscience'
radius = 100000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_bioscience = json_normalize(venues)
df_bioscience.head()
# Out:
# bioscience .... OK!
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 1  [{'id': '4bf58dd8d48988d125941735', 'name': 'T...    False
#
#                          id    location.address location.cc  \
# 0  4f58dcb2e4b0bdfd0f220dd0  Rue Édouard Berlin          BE
# 1  4ec64abef9f43c0ee691095d   Rue Granbonpré 11          BE
#
#         location.city location.country location.crossStreet  \
# 0  Mont-Saint-Guibert         Belgique                  NaN
# 1  Mont-Saint-Guibert           België                   BE
#
#    location.distance                          location.formattedAddress  \
# 0             103521  [Rue Édouard Berlin, 1348 Mont Saint Guibert, ...
# 1             102406  [Rue Granbonpré 11 (BE), 1435 Mont-Saint-Guibe...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 50.65958502928284...     50.659585
# 1  [{'label': 'display', 'lat': 50.66045089679621...     50.660451
#
#    location.lng location.postalCode  location.state                    name  \
# 0      4.626665                1348  Brabant Wallon                  Celyad
# 1      4.642419                1435             NaN  Promethera Biosciences
#
#      referralId
# 0  v-1584191933
# 1  v-1584191933

# %% [markdown]
# ### 2.5. DNA related venues

# %%
search_query = 'DNA'
radius = 100000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()

# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_DNA = json_normalize(venues)
df_DNA.head()
# Out:
# DNA .... OK!
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 1  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 2                                                 []    False
# 3  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 4  [{'id': '4bf58dd8d48988d1f9931735', 'name': 'R...    False
#
#                          id location.address location.cc location.city  \
# 0  4e731ca145dd41e9ccc6f7ac     Promenade 12          NL       Heerlen
# 1  4da817d604376c33687f0fa3              NaN          NL    Maastricht
# 2  4c28586597d00f4738ba3fea              NaN          DE           NaN
# 3  5053259be4b0e7ceb5d2056e    Pelsstraat 29          BE   Drieslinter
# 4  4dab1e0fcda1652a2b9bd0d2   5656 Eindhoven          NL     Eindhoven
#
#   location.country  location.distance  \
# 0        Nederland              14508
# 1        Nederland              26680
# 2      Deutschland              56213
# 3           België              73489
# 4        Nederland              82912
#
#                      location.formattedAddress  \
# 0   [Promenade 12, 6411 JK Heerlen, Nederland]
# 1                      [Maastricht, Nederland]
# 2                                [Deutschland]
# 3    [Pelsstraat 29, 3350 Drieslinter, België]
# 4  [5656 Eindhoven, 5656 Eindhoven, Nederland]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 50.88777422, 'lng...     50.887774
# 1  [{'label': 'display', 'lat': 50.832841, 'lng':...     50.832841
# 2  [{'label': 'display', 'lat': 50.94844669383953...     50.948447
# 3  [{'label': 'display', 'lat': 50.84848, 'lng': ...     50.848480
# 4  [{'label': 'display', 'lat': 51.40511546782327...     51.405115
#
#    location.lng location.postalCode  location.state        name    referralId  \
# 0      5.976819             6411 JK         Limburg    La Place  v-1584192489
# 1      5.715286                 NaN         Limburg  DNanalysis  v-1584192489
# 2      6.836022                 NaN             NaN  Privathaus  v-1584192489
# 3      5.045309                3350  Vlaams-Brabant        D-na  v-1584192489
# 4      5.448161                5656   Noord-Brabant    DNA Brug  v-1584192489
#
#   venuePage.id
# 0    571913598
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ### 2.6. Lets investigate columns of the 5 dataframes

# %%
print ('Are all the columns of the df_genetics and df_biology the same? ', all(df_genetics.columns == df_biology.columns))
# Out:
# Are all the columns of the df_genetics and df_biology the same?  True

# %%
print ('Are all the columns of the df_bioscience and df_DNA the same? ', all(df_bioscience.columns == df_DNA.columns))
# Out:
# Are all the columns of the df_bioscience and df_DNA the same?  False

# %% [markdown]
# **We see that all columns of the dataframes are not the same. Lets depict their shapes**

# %%
print('shape of the dataframe genetics: ', df_genetics.shape)
print('shape of the dataframe biology: ', df_biology.shape)
print('shape of the dataframe bioscience: ', df_bioscience.shape)
print('shape of the dataframe DNA: ', df_DNA.shape)
# Out:
# shape of the dataframe genetics:  (7, 16)
# shape of the dataframe biology:  (9, 16)
# shape of the dataframe bioscience:  (2, 17)
# shape of the dataframe DNA:  (15, 17)

# %% [markdown]
# **Now lets put lables of each dataframe so that we can use this information later on**

# %%
df_genetics['label'] = 'genetics'

# %%
df_biology['label'] = 'biology'
df_bioscience['label'] = 'bioscience'
df_DNA['label'] = 'DNA'

# %%
print('shape of the dataframe genetics: ', df_genetics.shape)
print('shape of the dataframe biology: ', df_biology.shape)
print('shape of the dataframe bioscience: ', df_bioscience.shape)
print('shape of the dataframe DNA: ', df_DNA.shape)
# Out:
# shape of the dataframe genetics:  (7, 17)
# shape of the dataframe biology:  (9, 17)
# shape of the dataframe bioscience:  (2, 18)
# shape of the dataframe DNA:  (15, 18)

# %% [markdown]
# **Lets, combine all dataframes as shown below**

# %%
df = pd.concat([df_genetics, df_biology, df_bioscience, df_DNA], ignore_index=True, sort=False)
df.shape
# Out:
# (33, 19)

# %%
df
# Out:
#                                            categories  hasPerk  \
# 0   [{'id': '5744ccdfe4b0c0459246b4d6', 'name': 'L...    False
# 1   [{'id': '4bf58dd8d48988d19b941735', 'name': 'C...    False
# 2   [{'id': '4f4531b14b9074f6e4fb0103', 'name': 'M...    False
# 3   [{'id': '4bf58dd8d48988d1a5941735', 'name': 'C...    False
# 4   [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 5   [{'id': '4f4531b14b9074f6e4fb0103', 'name': 'M...    False
# 6   [{'id': '4bf58dd8d48988d104941735', 'name': 'M...    False
# 7   [{'id': '4bf58dd8d48988d198941735', 'name': 'C...    False
# 8   [{'id': '4bf58dd8d48988d1a5941735', 'name': 'C...    False
# 9   [{'id': '4bf58dd8d48988d1a5941735', 'name': 'C...    False
# 10  [{'id': '4bf58dd8d48988d1a5941735', 'name': 'C...    False
# 11  [{'id': '4bf58dd8d48988d19b941735', 'name': 'C...    False
# 12  [{'id': '5744ccdfe4b0c0459246b4d6', 'name': 'L...    False
# 13  [{'id': '4bf58dd8d48988d1a5941735', 'name': 'C...    False
# 14  [{'id': '5744ccdfe4b0c0459246b4d6', 'name': 'L...    False
# 15  [{'id': '4bf58dd8d48988d1b1941735', 'name': 'C...    False
# 16  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 17  [{'id': '4bf58dd8d48988d125941735', 'name': 'T...    False
# 18  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 19  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 20                                                 []    False
# 21  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 22  [{'id': '4bf58dd8d48988d1f9931735', 'name': 'R...    False
# 23  [{'id': '4f04aa0c2fb6e1c99f3db0b8', 'name': 'N...    False
# 24  [{'id': '4d954af4a243a5684765b473', 'name': 'V...    False
# 25  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 26  [{'id': '4f04aa0c2fb6e1c99f3db0b8', 'name': 'N...    False
# 27  [{'id': '4bf58dd8d48988d125941735', 'name': 'T...    False
# 28  [{'id': '52e81612bcbc57f1066b7a3d', 'name': 'A...    False
# 29  [{'id': '4bf58dd8d48988d19b941735', 'name': 'C...    False
# 30  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...    False
# 31  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...    False
# 32  [{'id': '4bf58dd8d48988d1a5941735', 'name': 'C...    False
#
#                           id               location.address location.cc  \
# 0   59db56b45a2c9117457d61ca                            NaN          NL
# 1   4d4de72b671fba7a4351f352             Zülpicher Str. 47a          DE
# 2   55eea84a498eabd1ea6c1551              Kapucijnenvoer 33          BE
# 3   513d90a1e4b07fb438cb31e6  UZ Leuven Campus Gasthuisberg          BE
# 4   4c8dc146ad70a14343f1830f                 Spoorstraat 69          NL
# 5   5146beece4b0853bfb17538d      geert grooteplein zuid 10          NL
# 6   4cfe02abd8468cfaff64036c                            NaN          NL
# 7   4cdb217cd549548122353ab2       Joseph-Stelzmann-Str. 9b          DE
# 8   4e9689c95c5cc3f498243ed6             Von-Liebig-Str. 20          DE
# 9   4e5604d7ae6040e96dfd3b6e           Celestijnenlaan 200G          BE
# 10  4f0fae2ae4b0253d4af98901                            NaN          NL
# 11  55c32b7e498ec2a4d07df0bd        Kasteelpark Arenberg 31          BE
# 12  58c96519c682352c1e0aae72                            NaN          BE
# 13  546ddcd1498e699dadd5e5cb                  Herestraat 40          BE
# 14  58cf7b792f91cb28ec64ac4d                            NaN          BE
# 15  52f3bccb498e406924dceceb                            NaN          BE
# 16  4f58dcb2e4b0bdfd0f220dd0             Rue Édouard Berlin          BE
# 17  4ec64abef9f43c0ee691095d              Rue Granbonpré 11          BE
# 18  4e731ca145dd41e9ccc6f7ac                   Promenade 12          NL
# 19  4da817d604376c33687f0fa3                            NaN          NL
# 20  4c28586597d00f4738ba3fea                            NaN          DE
# 21  5053259be4b0e7ceb5d2056e                  Pelsstraat 29          BE
# 22  4dab1e0fcda1652a2b9bd0d2                 5656 Eindhoven          NL
# 23  507c0803e4b0199a34df893f                            NaN          NL
# 24  584c2c72110d0322742b8966          Mechelsesteenweg 1062          BE
# 25  4f182d0ee4b03334279a4d57            Interleuvenlaan 12a          BE
# 26  5aafd84bb546180dba365fb3                            NaN          BE
# 27  529f35f2498e351fe1adc2a1           Rue Louis de Geer, 6          BE
# 28  57b2da90498ee94549477af8                            NaN          BE
# 29  4e1af2c5ae60e3765f4c48b3                   Toernooiveld          NL
# 30  4f3badf4e4b03c8a49bf478f                            NaN          NL
# 31  4d12087d9844b60c568fb8d4                            NaN          NL
# 32  5763d974498ecdeadae4ab5d               Lovensdijkstraat          NL
#
#          location.city location.country  location.distance  \
# 0                  NaN        Nederland              26778
# 1                 Köln      Deutschland              62259
# 2               Leuven           België              98450
# 3               Leuven           België              99872
# 4              Boxmeer        Nederland              97440
# 5             Nijmegen        Nederland             117668
# 6             Nijmegen        Nederland             118410
# 7                 Köln      Deutschland              61222
# 8            Rheinbach      Deutschland              63241
# 9             Heverlee           België              99581
# 10                Best        Nederland              94713
# 11            Heverlee           België              98618
# 12                 NaN           België              99959
# 13              Leuven           België              99832
# 14                 NaN           België              99920
# 15                 NaN           België             102556
# 16  Mont-Saint-Guibert         Belgique             103521
# 17  Mont-Saint-Guibert           België             102406
# 18             Heerlen        Nederland              14508
# 19          Maastricht        Nederland              26680
# 20                 NaN      Deutschland              56213
# 21         Drieslinter           België              73489
# 22           Eindhoven        Nederland              82912
# 23                 NaN        Nederland              83981
# 24              Herent           België             102670
# 25            Heverlee           België              95924
# 26                 NaN           België              97319
# 27    Louvain-la-Neuve         Belgique             103560
# 28                 NaN           België             104110
# 29            Nijmegen        Nederland             117723
# 30                 NaN        Nederland             122928
# 31           Hazeldonk        Nederland             123226
# 32               Breda        Nederland             127516
#
#                             location.formattedAddress  \
# 0                                         [Nederland]
# 1       [Zülpicher Str. 47a, 50674 Köln, Deutschland]
# 2            [Kapucijnenvoer 33, 3000 Leuven, België]
# 3   [UZ Leuven Campus Gasthuisberg, 3000 Leuven, B...
# 4        [Spoorstraat 69, 5831 CK Boxmeer, Nederland]
# 5   [geert grooteplein zuid 10, 6525 GA Nijmegen, ...
# 6                               [Nijmegen, Nederland]
# 7   [Joseph-Stelzmann-Str. 9b, 50931 Köln, Deutsch...
# 8   [Von-Liebig-Str. 20, 53359 Rheinbach, Deutschl...
# 9       [Celestijnenlaan 200G, 3001 Heverlee, België]
# 10                                  [Best, Nederland]
# 11   [Kasteelpark Arenberg 31, 3001 Heverlee, België]
# 12                                           [België]
# 13               [Herestraat 40, 3000 Leuven, België]
# 14                                           [België]
# 15                                           [België]
# 16  [Rue Édouard Berlin, 1348 Mont Saint Guibert, ...
# 17  [Rue Granbonpré 11 (BE), 1435 Mont-Saint-Guibe...
# 18         [Promenade 12, 6411 JK Heerlen, Nederland]
# 19                            [Maastricht, Nederland]
# 20                                      [Deutschland]
# 21          [Pelsstraat 29, 3350 Drieslinter, België]
# 22        [5656 Eindhoven, 5656 Eindhoven, Nederland]
# 23                                        [Nederland]
# 24       [Mechelsesteenweg 1062, 3020 Herent, België]
# 25       [Interleuvenlaan 12a, 3001 Heverlee, België]
# 26                                           [België]
# 27  [Rue Louis de Geer, 6, 1348 Louvain-la-Neuve, ...
# 28                                           [België]
# 29                [Toernooiveld, Nijmegen, Nederland]
# 30                                        [Nederland]
# 31                             [Hazeldonk, Nederland]
# 32       [Lovensdijkstraat, 4818 AJ Breda, Nederland]
#
#                               location.labeledLatLngs  location.lat  \
# 0   [{'label': 'display', 'lat': 50.836662, 'lng':...     50.836662
# 1   [{'label': 'display', 'lat': 50.92739657634655...     50.927397
# 2   [{'label': 'display', 'lat': 50.87958022274423...     50.879580
# 3   [{'label': 'display', 'lat': 50.88057991020145...     50.880580
# 4   [{'label': 'display', 'lat': 51.64695562065073...     51.646956
# 5   [{'label': 'display', 'lat': 51.8246002197266,...     51.824600
# 6   [{'label': 'display', 'lat': 51.83498061605513...     51.834981
# 7   [{'label': 'display', 'lat': 50.92538278319003...     50.925383
# 8   [{'label': 'display', 'lat': 50.63178898813339...     50.631789
# 9   [{'label': 'display', 'lat': 50.86227832411388...     50.862278
# 10  [{'label': 'display', 'lat': 51.5075, 'lng': 5...     51.507500
# 11  [{'label': 'display', 'lat': 50.86480386250966...     50.864804
# 12  [{'label': 'display', 'lat': 50.879324, 'lng':...     50.879324
# 13  [{'label': 'display', 'lat': 50.87979739040283...     50.879797
# 14  [{'label': 'display', 'lat': 50.880021, 'lng':...     50.880021
# 15  [{'label': 'display', 'lat': 51.311623, 'lng':...     51.311623
# 16  [{'label': 'display', 'lat': 50.65958502928284...     50.659585
# 17  [{'label': 'display', 'lat': 50.66045089679621...     50.660451
# 18  [{'label': 'display', 'lat': 50.88777422, 'lng...     50.887774
# 19  [{'label': 'display', 'lat': 50.832841, 'lng':...     50.832841
# 20  [{'label': 'display', 'lat': 50.94844669383953...     50.948447
# 21  [{'label': 'display', 'lat': 50.84848, 'lng': ...     50.848480
# 22  [{'label': 'display', 'lat': 51.40511546782327...     51.405115
# 23  [{'label': 'display', 'lat': 51.52793042292458...     51.527930
# 24  [{'label': 'display', 'lat': 50.92440937629001...     50.924409
# 25  [{'label': 'display', 'lat': 50.84798844055888...     50.847988
# 26  [{'label': 'display', 'lat': 50.881443, 'lng':...     50.881443
# 27  [{'label': 'display', 'lat': 50.666719, 'lng':...     50.666719
# 28  [{'label': 'display', 'lat': 51.015739, 'lng':...     51.015739
# 29  [{'label': 'display', 'lat': 51.8258907, 'lng'...     51.825891
# 30  [{'label': 'display', 'lat': 51.49268407910959...     51.492684
# 31  [{'label': 'display', 'lat': 51.50184652956327...     51.501847
# 32  [{'label': 'display', 'lat': 51.585175, 'lng':...     51.585175
#
#     location.lng location.postalCode       location.state  \
# 0       5.715358                 NaN                  NaN
# 1       6.936851               50674  Nordrhein-Westfalen
# 2       4.693267                3000       Vlaams-Brabant
# 3       4.673076                3000       Vlaams-Brabant
# 4       5.938949             5831 CK        Noord-Brabant
# 5       5.866290             6525 GA           Gelderland
# 6       5.917804                 NaN           Gelderland
# 7       6.922402               50931  Nordrhein-Westfalen
# 8       6.951376               53359  Nordrhein-Westfalen
# 9       4.674423                3001       Vlaams-Brabant
# 10      5.390278                 NaN        Noord-Brabant
# 11      4.688544                3001       Vlaams-Brabant
# 12      4.671621                 NaN                  NaN
# 13      4.673523                3000       Vlaams-Brabant
# 14      4.672292                 NaN                  NaN
# 15      4.891198                 NaN                  NaN
# 16      4.626665                1348       Brabant Wallon
# 17      4.642419                1435                  NaN
# 18      5.976819             6411 JK              Limburg
# 19      5.715286                 NaN              Limburg
# 20      6.836022                 NaN                  NaN
# 21      5.045309                3350       Vlaams-Brabant
# 22      5.448161                5656        Noord-Brabant
# 23      5.979597                 NaN                  NaN
# 24      4.641925                3020       Vlaams-Brabant
# 25      4.724812                3001       Vlaams-Brabant
# 26      4.709795                 NaN                  NaN
# 27      4.624609                1348       Brabant Wallon
# 28      4.650432                 NaN                  NaN
# 29      5.876260                 NaN           Gelderland
# 30      4.744450                 NaN                  NaN
# 31      4.751236                 NaN        Noord-Brabant
# 32      4.789791             4818 AJ        Noord-Brabant
#
#                                                  name    referralId  \
# 0                            Klinische Genetica Mumc+  v-1584191445
# 1                     CECAD at Institute for Genetics  v-1584191445
# 2                                Forensische Genetica  v-1584191445
# 3                             Autoimmune Genetics Lab  v-1584191445
# 4                                    Hendrix Genetics  v-1584191445
# 5                       Umc St.Radboud Human Genetics  v-1584191445
# 6      Human Genetics Antropogenetica UMC St. Radboud  v-1584191445
# 7           Max-Planck-Institute for Biology of Aging  v-1584191578
# 8                               Molecular Biology Lab  v-1584191578
# 9   Biomol | Laboratory Of Biomolecular Dynamics, ...  v-1584191578
# 10                                       Biology Room  v-1584191578
# 11                             Functional Biology Lab  v-1584191578
# 12                      lab for developmental biology  v-1584191578
# 13                                Systems Biology Lab  v-1584191578
# 14            skeletal biology and engineering center  v-1584191578
# 15                             in Fred's biology boek  v-1584191578
# 16                                             Celyad  v-1584191933
# 17                             Promethera Biosciences  v-1584191933
# 18                                           La Place  v-1584192489
# 19                                         DNanalysis  v-1584192489
# 20                                         Privathaus  v-1584192489
# 21                                               D-na  v-1584192489
# 22                                           DNA Brug  v-1584192489
# 23                                     iD Nagelstudio  v-1584192489
# 24                     DnA Dierenartsencentrum Herent  v-1584192489
# 25                        Integrated Dna Technologies  v-1584192489
# 26                                          V&D Nails  v-1584192489
# 27                                          DNAlytics  v-1584192489
# 28                                            DNA:lab  v-1584192489
# 29          Marjolein Kriek's DNA seqentie standbeeld  v-1584192489
# 30                              DNA UNITED FORWARDERS  v-1584192489
# 31                                     DNA Forwarders  v-1584192489
# 32                           LAB DNA & Biotechnologie  v-1584192489
#
#          label location.crossStreet venuePage.id
# 0     genetics                  NaN          NaN
# 1     genetics                  NaN          NaN
# 2     genetics                  NaN          NaN
# 3     genetics                  NaN          NaN
# 4     genetics                  NaN          NaN
# 5     genetics                  NaN          NaN
# 6     genetics                  NaN          NaN
# 7      biology                  NaN          NaN
# 8      biology                  NaN          NaN
# 9      biology                  NaN          NaN
# 10     biology                  NaN          NaN
# 11     biology                  NaN          NaN
# 12     biology                  NaN          NaN
# 13     biology                  NaN          NaN
# 14     biology                  NaN          NaN
# 15     biology                  NaN          NaN
# 16  bioscience                  NaN          NaN
# 17  bioscience                   BE          NaN
# 18         DNA                  NaN    571913598
# 19         DNA                  NaN          NaN
# 20         DNA                  NaN          NaN
# 21         DNA                  NaN          NaN
# 22         DNA                  NaN          NaN
# 23         DNA                  NaN          NaN
# 24         DNA                  NaN          NaN
# 25         DNA                  NaN          NaN
# 26         DNA                  NaN          NaN
# 27         DNA                  NaN          NaN
# 28         DNA                  NaN          NaN
# 29         DNA                  NaN          NaN
# 30         DNA                  NaN          NaN
# 31         DNA                  NaN          NaN
# 32         DNA                  NaN          NaN

# %% [markdown]
# **Now our dataframe is ready to for cleaning,  EDA and further analysis**
#
# **But before that, lets visualize these venues**

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=7) # generate map centred around Aachen

# add a red circle marker to represent Aachen
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Aachen',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the venues that are nearby as blue circle markers
for lat, lng, label in zip(df['location.lat'], df['location.lng'], df['label']):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **to see the plot, please refer to the png file named as "biotechnology venues that are nearby aachen" in the my coursera capstone repocitory**

# %% [markdown]
# ## How we are going to analyse the data?
#
# Now, we know the locations of nearby venues of Aachen. We have seen that there is no biotechnology venue within 100 km of Aachen. Moreover, there is no any venue in the southern part of the Aachen. On the other hand, there are 33 venues that are related to my contractors business.
#
# Therefore, we have to explore these venues more and learn how they are related with our business.
#
# We will investigate why there is no any venues in the souther part of Aachen
#
# We will increase the radius to see how the distribution of the other venues changes
#
# We will also investigate posible target markets of our business such as "genetic diagnostic centers" or "pharmaceutical companies" and their distributions
#
# And finally, we will recommend some possible locations for their laboratory.
